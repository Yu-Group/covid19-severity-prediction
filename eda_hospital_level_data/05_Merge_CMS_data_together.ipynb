# %% [markdown]
# # Merge data with CMS numbers
#
# Data from the following sources:
# - 03_teaching_hospital_info.xlsx. EDA link: [01_EDA_teaching_hospital](01_EDA_teaching_hospital.ipynb)
# - 04_CMS_hospital_info.csv EDA link: [06_EDA_CMS_hospital_info.ipynb](06_EDA_CMS_hospital_info.ipynb)
# - 05_tbl_usr_rpt_5103.xlsx EDA link: [04_EDA_data_from_Sam](04_EDA_data_from_Sam.ipynb)
# - 06_tbl_usr_rpt_5104.xlsx EDA link: [04_EDA_data_from_Sam](04_EDA_data_from_Sam.ipynb)

# %%
import pandas as pd
import numpy as np

# %%
# load data
raw03 = pd.read_excel(
    "../data/hospital_level_info//03_teaching_hospital_info.xlsx",
    index_col=0,
)
raw04 = pd.read_csv("../data/hospital_level_info/04_CMS_hospital_info.csv")
raw05 = pd.read_excel("../data/hospital_level_info/05_tbl_usr_rpt_5103.xlsx")
raw06 = pd.read_excel("../data/hospital_level_info/06_tbl_usr_rpt_5104.xlsx")

# %%
# visualize the shape of all the tables
raw03.shape, raw04.shape, raw05.shape, raw06.shape
# Out:
# ((1344, 15), (5339, 29), (7024, 20), (7024, 131))

# %%
# preprocess add a string ID to raw03 and raw04
raw03['CMS Certification Number'] = raw03['CCN'].astype(str).apply(lambda x: x.zfill(6))
raw04['CMS Certification Number'] = raw04['Facility ID']

# %%
# visualize the rows in raw03 that has facility id not in raw04
raw03[~raw03['CMS Certification Number'].isin(raw04['CMS Certification Number'])].head()
# Out:
#        CCN        TIN                         Hospital Name  \
# ROW
# 21   10137  636001579           Cooper Green Mercy Hospital
# 22   10152  203713023                        Infirmary West
# 55   40042  710236932          Crittenden Regional Hospital
# 62   43026  710236856  Baptist Health Rehabilitation Instit
# 96   50146  951683875     City Of Hope National Medical Ctr
#
#                 PECOS Legal Business Name              Street Address PO Box  \
# ROW
# 21            Jefferson County Commission     1515 Sixth Avenue South    NaN
# 22       Infirmary Health Hospitals, Inc.             5600 Girby Road    144
# 55        Crittenden Hospital Association                200 Tyler St   2248
# 62                         Baptist Health  9601  Baptist Health Drive    NaN
# 96   City Of Hope National Medical Center         1500 E. Duarte Road    NaN
#
#              City State  Zip Code           Street Address 1 Street Address 2  \
# ROW
# 21     Birmingham    AL     35233             1515 6th Ave S              NaN
# 22         Mobile    AL     36693              5600 Girby Rd              NaN
# 55   West Memphis    AR     72303            200 W Tyler Ave              NaN
# 62    Little Rock    AR     72205  9601 Baptist Health Drive              NaN
# 96         Duarte    CA     91010           1500 E Duarte Rd              NaN
#
#            City.1 State.1  Zip Code.1 Facility ID CMS Certification Number
# ROW
# 21     Birmingham      AL       35233      010137                   010137
# 22         Mobile      AL       36693      010152                   010152
# 55   West Memphis      AR       72301      040042                   040042
# 62    Little Rock      AR       72205      043026                   043026
# 96         Duarte      CA       91010      050146                   050146

# %%
# visualize the rows in raw04 that has facility id not in raw05
raw04[~raw04['CMS Certification Number'].isin(raw05['CMS Certification Number'])].head()
# Out:
#     Facility ID                                  Facility Name  \
# 46       194085         COMPASS BEHAVIORAL CENTER OF LAFAYETTE
# 91       670117               TEXAS GENERAL HOSPITAL- VZRMC LP
# 107      390302                  BARIX CLINICS OF PENNSYLVANIA
# 148      244005  CHILD & ADOLESCENT BEHAVIORAL HEALTH SERVICES
# 190      194007             NORTHLAKE BEHAVIORAL HEALTH SYSTEM
#
#                       Address          City State  ZIP Code  County Name  \
# 46    312 YOUNGSVILLE HIGHWAY     LAFAYETTE    LA     70508    LAFAYETTE
# 91           707 N WALDRIP ST  GRAND SALINE    TX     75140    VAN ZANDT
# 107       280 MIDDLETOWN ROAD     LANGHORNE    PA     19047        BUCKS
# 148  1701 TECHNOLOGY DRIVE NE       WILLMAR    MN     56201    KANDIYOHI
# 190         23515 HIGHWAY 190    MANDEVILLE    LA     70448  ST. TAMMANY
#
#        Phone Number         Hospital Type              Hospital Ownership  \
# 46   (337) 534-4655           Psychiatric                     Proprietary
# 91   (903) 962-5200  Acute Care Hospitals                     Proprietary
# 107  (267) 572-3100  Acute Care Hospitals                     Proprietary
# 148  (320) 231-5405           Psychiatric              Government - State
# 190  (985) 626-6300           Psychiatric  Voluntary non-profit - Private
#
#      ...  Patient experience national comparison  \
# 46   ...                           Not Available
# 91   ...                           Not Available
# 107  ...                           Not Available
# 148  ...                           Not Available
# 190  ...                           Not Available
#
#     Patient experience national comparison footnote  \
# 46                                             19.0
# 91                                             16.0
# 107                                            16.0
# 148                                            19.0
# 190                                            19.0
#
#     Effectiveness of care national comparison  \
# 46                              Not Available
# 91                              Not Available
# 107                             Not Available
# 148                             Not Available
# 190                             Not Available
#
#      Effectiveness of care national comparison footnote  \
# 46                                                19.0
# 91                                                 5.0
# 107                                                5.0
# 148                                               19.0
# 190                                               19.0
#
#     Timeliness of care national comparison  \
# 46                           Not Available
# 91            Same as the national average
# 107                          Not Available
# 148                          Not Available
# 190                          Not Available
#
#      Timeliness of care national comparison footnote  \
# 46                                              19.0
# 91                                               NaN
# 107                                             16.0
# 148                                             19.0
# 190                                             19.0
#
#     Efficient use of medical imaging national comparison  \
# 46                                       Not Available
# 91                                       Not Available
# 107                                      Not Available
# 148                                      Not Available
# 190                                      Not Available
#
#      Efficient use of medical imaging national comparison footnote  \
# 46                                                19.0
# 91                                                16.0
# 107                                               16.0
# 148                                               19.0
# 190                                               19.0
#
#                          Location  CMS Certification Number
# 46   POINT (-91.991048 30.155424)                    194085
# 91   POINT (-95.721737 32.679193)                    670117
# 107  POINT (-74.884542 40.181801)                    390302
# 148  POINT (-95.019258 45.142263)                    244005
# 190   POINT (-90.02169 30.345064)                    194007
#
# [5 rows x 30 columns]

# %%
# preprocess merge all the data using CMS ID
merged = raw05.merge(raw06)
merged = merged.merge(raw04, how='outer', on='CMS Certification Number')
merged = merged.merge(raw03, how='outer', on='CMS Certification Number')

# %%
merged.to_csv("../intermediate/03_hospital_level_info_merged.csv")
