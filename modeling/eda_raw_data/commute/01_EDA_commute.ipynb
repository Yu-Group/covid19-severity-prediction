# %% [markdown]
# # EDA on commute data

# %%
import pandas as pd
import numpy as np

# %%
# load data
table1 = pd.read_excel(
    '../data/commute/table1.xlsx',
    #header=5,
    skiprows=[0,1,2,3,4,5, 139440, 139441],
    dtype=str
)
table1.columns = [
    'Resident State FIPS',
    'Resident County FIPS',
    'Resident State Name',
    'Resident County Name',
    'Work State FIPS',
    'Work County FIPS',
    'Work State Name',
    'Work County Name',
    'commute',
    'error',
]

# %%
# load data: county info
county_info = pd.read_csv('../data/02_county_FIPS.csv', dtype=str, index_col=0)

# %%
# preprocess the table : change the double float type
table1['commute'] = table1['commute'].astype(np.float)
table1['error'] = table1['error'].astype(np.float)

# %%
# preprocess: change the county FIPS
table1['Work State FIPS'] = table1['Work State FIPS'].apply(lambda x : x[1:] if type(x) == str else np.nan)
table1['Resident County FIPS'] = table1['Resident State FIPS'] + table1['Resident County FIPS']
table1['Work County FIPS'] = table1['Work State FIPS'] + table1['Work County FIPS']

# %%
# visualize the california data
table1[table1['Resident State Name'] == 'California']
# Out:
#       Resident State FIPS Resident County FIPS Resident State Name  \
# 6585                   06                06001          California
# 6586                   06                06001          California
# 6587                   06                06001          California
# 6588                   06                06001          California
# 6589                   06                06001          California
# ...                   ...                  ...                 ...
# 10412                  06                06115          California
# 10413                  06                06115          California
# 10414                  06                06115          California
# 10415                  06                06115          California
# 10416                  06                06115          California
#
#       Resident County Name Work State FIPS Work County FIPS Work State Name  \
# 6585        Alameda County              01            01089         Alabama
# 6586        Alameda County              04            04013         Arizona
# 6587        Alameda County              04            04019         Arizona
# 6588        Alameda County              05            05007        Arkansas
# 6589        Alameda County              06            06001      California
# ...                    ...             ...              ...             ...
# 10412          Yuba County              32            32031          Nevada
# 10413          Yuba County              41            41027          Oregon
# 10414          Yuba County              45            45083  South Carolina
# 10415          Yuba County              48            48029           Texas
# 10416          Yuba County              03              NaN          Mexico
#
#          Work County Name   commute   error
# 6585       Madison County       4.0     6.0
# 6586      Maricopa County     106.0    48.0
# 6587          Pima County      31.0    37.0
# 6588        Benton County      13.0    21.0
# 6589       Alameda County  462270.0  3414.0
# ...                   ...       ...     ...
# 10412       Washoe County      65.0    71.0
# 10413   Hood River County       7.0    13.0
# 10414  Spartanburg County       5.0     8.0
# 10415        Bexar County      19.0    27.0
# 10416                 NaN       1.0     4.0
#
# [3832 rows x 10 columns]

# %%
# visualize the states with the most people go to work
table1.groupby('Work State Name')['commute'].sum().sort_values(ascending=False).head()
# Out:
# Work State Name
# California    16864403.0
# Texas         11961894.0
# New York       9417672.0
# Florida        8385355.0
# Illinois       5971813.0
# Name: commute, dtype: float64

# %%
# visualize the states with the most people resides
table1.groupby('Resident State Name')['commute'].sum().sort_values(ascending=False).head()
# Out:
# Resident State Name
# California    16869052.0
# Texas         11966019.0
# New York       9064986.0
# Florida        8432513.0
# Illinois       5983836.0
# Name: commute, dtype: float64

# %%
# preprocess find the county FIPS that are in this data but not in county_info
missed_counties = set(table1['Resident County FIPS'].unique()) - set(county_info['FIPS'])
table1.loc[table1['Resident County FIPS'].isin(missed_counties), 'Resident County Name'].unique()
# Out:
# array([], dtype=object)

# %%
# visualize people from CA to NY
table1[(table1['Resident State Name'] == 'California') & (table1['Work State Name'] == 'New York')]
# Out:
#       Resident State FIPS Resident County FIPS Resident State Name  \
# 6673                   06                06001          California
# 6674                   06                06001          California
# 6675                   06                06001          California
# 6676                   06                06001          California
# 6677                   06                06001          California
# ...                   ...                  ...                 ...
# 10298                  06                06111          California
# 10299                  06                06111          California
# 10300                  06                06111          California
# 10369                  06                06113          California
# 10370                  06                06113          California
#
#       Resident County Name Work State FIPS Work County FIPS Work State Name  \
# 6673        Alameda County              36            36001        New York
# 6674        Alameda County              36            36007        New York
# 6675        Alameda County              36            36029        New York
# 6676        Alameda County              36            36047        New York
# 6677        Alameda County              36            36059        New York
# ...                    ...             ...              ...             ...
# 10298       Ventura County              36            36055        New York
# 10299       Ventura County              36            36061        New York
# 10300       Ventura County              36            36103        New York
# 10369          Yolo County              36            36061        New York
# 10370          Yolo County              36            36091        New York
#
#       Work County Name  commute  error
# 6673     Albany County      6.0   10.0
# 6674     Broome County     13.0   25.0
# 6675       Erie County      8.0   13.0
# 6676      Kings County     45.0   41.0
# 6677     Nassau County      4.0    6.0
# ...                ...      ...    ...
# 10298    Monroe County      9.0   19.0
# 10299  New York County     15.0   24.0
# 10300   Suffolk County      7.0   11.0
# 10369  New York County      8.0   13.0
# 10370  Saratoga County     16.0   28.0
#
# [112 rows x 10 columns]

# %%
# save data
table1.to_csv("../data/commute/table1.csv")

# %%
# load data
table2 = pd.read_excel(
    '../data/commute/table3.xlsx',
    #header=5,
    #skiprows=[0,1,2,3,4,5, 139440, 139441],
    dtype=str
)

# %%
table2
# Out:
#                                           State FIPS Code County FIPS Code  \
# 0                                                      01              001
# 1                                                      01              001
# 2                                                      01              001
# 3                                                      01              001
# 4                                                      01              001
# ...                                                   ...              ...
# 594382                                                 72              153
# 594383                                                 72              153
# 594384  Data are based on a sample and are subject to ...              NaN
# 594385  Flows are presented for MCDs for the 12 "stron...              NaN
# 594386  Source: U.S. Census Bureau, 2011-2015 American...              NaN
#
#        Minor Civil Division FIPS Code   State Name      County Name  \
# 0                                 NaN      Alabama   Autauga County
# 1                                 NaN      Alabama   Autauga County
# 2                                 NaN      Alabama   Autauga County
# 3                                 NaN      Alabama   Autauga County
# 4                                 NaN      Alabama   Autauga County
# ...                               ...          ...              ...
# 594382                            NaN  Puerto Rico  Yauco Municipio
# 594383                            NaN  Puerto Rico  Yauco Municipio
# 594384                            NaN          NaN              NaN
# 594385                            NaN          NaN              NaN
# 594386                            NaN          NaN              NaN
#
#        Minor Civil Division Name State FIPS Code.1 County FIPS Code.1  \
# 0                            NaN               001                001
# 1                            NaN               001                013
# 2                            NaN               001                021
# 3                            NaN               001                043
# 4                            NaN               001                047
# ...                          ...               ...                ...
# 594382                       NaN               072                153
# 594383                       NaN               NaN                NaN
# 594384                       NaN               NaN                NaN
# 594385                       NaN               NaN                NaN
# 594386                       NaN               NaN                NaN
#
#        Minor Civil Division FIPS Code.1                         State Name.1  \
# 0                                   NaN                              Alabama
# 1                                   NaN                              Alabama
# 2                                   NaN                              Alabama
# 3                                   NaN                              Alabama
# 4                                   NaN                              Alabama
# ...                                 ...                                  ...
# 594382                              NaN                          Puerto Rico
# 594383                              NaN  Other workplace outside of the U.S.
# 594384                              NaN                                  NaN
# 594385                              NaN                                  NaN
# 594386                              NaN                                  NaN
#
#           County Name.1 Minor Civil Division Name.1 Workers in Commuting Flow  \
# 0        Autauga County                         NaN                      8828
# 1         Butler County                         NaN                         6
# 2        Chilton County                         NaN                       504
# 3        Cullman County                         NaN                        27
# 4         Dallas County                         NaN                       296
# ...                 ...                         ...                       ...
# 594382  Yauco Municipio                         NaN                      4894
# 594383              NaN                         NaN                         8
# 594384              NaN                         NaN                       NaN
# 594385              NaN                         NaN                       NaN
# 594386              NaN                         NaN                       NaN
#
#        Margin of Error
# 0                  752
# 1                   10
# 2                  228
# 3                   44
# 4                  130
# ...                ...
# 594382             532
# 594383              13
# 594384             NaN
# 594385             NaN
# 594386             NaN
#
# [594387 rows x 14 columns]
