# %% [markdown]
# # EDA on CMS hospital info

# %% [markdown]
# The data is downloaded using [this script](../data/hospital_level_info/04_download_CMS_hospital_info.sh)

# %%
import pandas as pd
import numpy as np

# %%
# load data 04
raw = pd.read_csv("../data/hospital_level_info/04_CMS_hospital_info.csv")

# %%
# visualize the columns in raw
set(raw.columns)
# Out:
# {'Address',
#  'City',
#  'County Name',
#  'Effectiveness of care national comparison',
#  'Effectiveness of care national comparison footnote',
#  'Efficient use of medical imaging national comparison',
#  'Efficient use of medical imaging national comparison footnote',
#  'Emergency Services',
#  'Facility ID',
#  'Facility Name',
#  'Hospital Ownership',
#  'Hospital Type',
#  'Hospital overall rating',
#  'Hospital overall rating footnote',
#  'Location',
#  'Meets criteria for meaningful use of EHRs',
#  'Mortality national comparison',
#  'Mortality national comparison footnote',
#  'Patient experience national comparison',
#  'Patient experience national comparison footnote',
#  'Phone Number',
#  'Readmission national comparison',
#  'Readmission national comparison footnote',
#  'Safety of care national comparison',
#  'Safety of care national comparison footnote',
#  'State',
#  'Timeliness of care national comparison',
# ...

# %%
# visualize head of raw
raw.head()
# Out:
#   Facility ID                      Facility Name                    Address  \
# 0      031309             SAGE MEMORIAL HOSPITAL  STATE ROUTE 264 SOUTH 191
# 1      044021        WOODRIDGE BEHAVIORAL CENTER       600 NORTH 7TH STREET
# 2      100277           DOUGLAS GARDENS HOSPITAL            5200 NE 2ND AVE
# 3      104078  SUNCOAST BEHAVIORAL HEALTH CENTER             4480 51ST ST W
# 4      130063           TREASURE VALLEY HOSPITAL   8800 WEST EMERALD STREET
#
#            City State  ZIP Code County Name    Phone Number  \
# 0        GANADO    AZ     86505      APACHE  (928) 755-4541
# 1  WEST MEMPHIS    AR     72301  CRITTENDEN  (870) 394-4113
# 2         MIAMI    FL     33137  MIAMI-DADE  (305) 751-8626
# 3     BRADENTON    FL     34210     MANATEE  (941) 792-2222
# 4         BOISE    ID     83704         ADA  (208) 373-5000
#
#                Hospital Type              Hospital Ownership  ...  \
# 0  Critical Access Hospitals  Voluntary non-profit - Private  ...
# ...

# %% [markdown]
# Description of each column:
#
# TODO

# %%
# visualize the number of unique values in Facility ID
print("The number of unique values for Facility ID is {} out of {}.".format(
    len(raw['Facility ID'].unique()),
    len(raw)
))
# Out:
# The number of unique values for Facility ID is 5339 out of 5339.
