# %%
from data.load_data import load_data
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from viz import viz
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = load_data()
outcome = '#Cases_3/21/2020'
df = df.sort_values(date, ascending=False)
print(df.keys())
# Out:
# Index(['id', 'Header-FIPSStandCtyCode', 'EntityofFile',
#        'SecondaryEntityOfFile', 'DateofFile', 'DateofCreation', 'FileLength',
#        'StateName', 'StateNameAbbreviation', 'CountyName',
#        ...
#        '#Cases_3/12/2020', '#Cases_3/13/2020', '#Cases_3/14/2020',
#        '#Cases_3/15/2020', '#Cases_3/16/2020', '#Cases_3/17/2020',
#        '#Cases_3/18/2020', '#Cases_3/19/2020', '#Cases_3/20/2020',
#        '#Cases_3/21/2020'],
#       dtype='object', length=7209)

# %% [markdown]
# # cases by county

# %%
plt.hist(df[outcome], bins=100)
plt.yscale('log')
plt.show()

# %%
df[[outcome, 'StateName', 'CountyName']]
# Out:
#      #Cases_3/21/2020      StateName           CountyName
# 615              8115       New York             New York
# 635              1385       New York          Westchester
# 614              1234       New York               Nassau
# 941               934     Washington                 King
# 627               662       New York              Suffolk
# 242               548       Illinois                 Cook
# 951               447     Washington            Snohomish
# 367               418      Louisiana              Orleans
# 567               363     New Jersey               Bergen
# 69                351     California          Los Angeles
# 445               349       Michigan                Wayne
# 89                263     California          Santa Clara
# 623               262       New York             Rockland
# 438               229       Michigan              Oakland
# 415               177  Massachusetts            Middlesex
# 164               169        Florida           Miami-Dade
# 363               166      Louisiana            Jefferson
# 145               164        Florida              Broward
# 595               163       New York               Albany
# 83                148     California            San Diego
# 129               140    Connecticut            Fairfield
# 818               140      Tennessee             Davidson
# 980               126      Wisconsin            Milwaukee
# 554               126         Nevada                Clark
# 577               116     New Jersey            Middlesex
# 87                110     California            San Mateo
# 418               108  Massachusetts              Suffolk
# 572               107     New Jersey                Essex
# 434               101       Michigan               Macomb
# 204                99        Georgia               Fulton
# ..                ...            ...                  ...
# 333                 1       Kentucky              Daviess
# 335                 1       Kentucky             Franklin
# 327                 1         Kansas             Sedgwick
# 326                 1         Kansas                Riley
# 749                 1   Pennsylvania               Centre
# 319                 1         Kansas              Jackson
# 748                 1   Pennsylvania               Butler
# 323                 1         Kansas             Mitchell
# 318                 1         Kansas             Franklin
# 588                 1     New Mexico                  Lea
# 325                 1         Kansas                 Reno
# 322                 1         Kansas                 Linn
# 753                 1   Pennsylvania                 Erie
# 589                 1     New Mexico             McKinley
# 330                 1       Kentucky             Calloway
# 740                 1         Oregon                Union
# 331                 1       Kentucky            Christian
# 738                 1         Oregon                 Polk
# 754                 1   Pennsylvania             Franklin
# 537                 0        Montana                 Lake
# 949                 0     Washington             San Juan
# 75                  0     California                 Napa
# 154                 0        Florida            Highlands
# 357                 0      Louisiana            Claiborne
# 723                 0       Oklahoma             Stephens
# 385                 0          Maine              Hancock
# 921                 0       Virginia  Fredericksburg City
# 953                 0     Washington              Stevens
# 387                 0          Maine                 Knox
# 347                 0      Louisiana               Acadia
#
# [1002 rows x 3 columns]

# %% [markdown]
# # interactive plots

# %%
# filter by state
state = 'NY'
d = df[df["StateNameAbbreviation"] == state]

p = viz.plot_counties(d, 
                  variable_to_distribute="CensusPopulation2010",
                  variables_to_display=["UnemploymentRate,16+2014", "PerCapitaPersonalIncome2014",
                         "%<65withoutHealthInsurance2014"],
                 state=state)
show(p)
output_file("../results/NY.html", mode='inline')
save(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-688dfc7486b8> in <module>
#       4 d = df[df["StateNameAbbreviation"] == state]
#       5
# ----> 6 p = plot_counties(d,
#       7                   variable_to_distribute="CensusPopulation2010",
#       8                   variables_to_display=["UnemploymentRate,16+2014", "PerCapitaPersonalIncome2014",
#
# NameError: name 'plot_counties' is not defined
