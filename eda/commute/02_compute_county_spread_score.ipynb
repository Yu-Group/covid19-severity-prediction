# %% [markdown]
# # Compute county spread score

# %%
import numpy as np
import pandas as pd

# %%
# load data
table1 = pd.read_csv(
    "../../data/commute/table1.csv",
    index_col=0,
    dtype={
        'Resident County FIPS':str,
        'Work County FIPS':str,
        'Resident State FIPS':str,
        'Work State FIPS':str,
    },
)

# %%
# visualize the head
table1.head()
# Out:
#   Resident State FIPS Resident County FIPS Resident State Name  \
# 0                  01                01001             Alabama
# 1                  01                01001             Alabama
# 2                  01                01001             Alabama
# 3                  01                01001             Alabama
# 4                  01                01001             Alabama
#
#   Resident County Name Work State FIPS Work County FIPS Work State Name  \
# 0       Autauga County              01            01001         Alabama
# 1       Autauga County              01            01013         Alabama
# 2       Autauga County              01            01021         Alabama
# 3       Autauga County              01            01043         Alabama
# 4       Autauga County              01            01047         Alabama
#
#   Work County Name  commute  error
# 0   Autauga County   8828.0  752.0
# 1    Butler County      6.0   10.0
# 2   Chilton County    504.0  228.0
# 3   Cullman County     27.0   44.0
# 4    Dallas County    296.0  130.0

# %%
# preprocess: drop unused cols
table1 = table1.drop(['Resident State FIPS', 'Work State FIPS'], axis=1)

# %%
# preprocess: drop rows with missing Work County FIPS, usually these are foreign places
table1 = table1.dropna(subset=['Work County FIPS'])

# %% [markdown]
# ## Method 1: use resident commute sum to normalize

# %%
# preprocess: compute the lower bound for commute
table1['resident_weight'] = np.maximum(0, table1['commute'] - table1['error'])
total_weight = table1.groupby("Resident County FIPS")['resident_weight'].sum()

# %%
# preprocess: compute the weight
table1 = table1.join(total_weight, on='Resident County FIPS', rsuffix='_total')
table1['resident_weight'] = table1['resident_weight'] / table1['resident_weight_total']

# %%
# visualize the high resident weight areas
table1[table1['resident_weight'] > 0.99]
# Out:
#        Resident County FIPS Resident State Name        Resident County Name  \
# 2959                  02013              Alaska      Aleutians East Borough
# 2963                  02016              Alaska  Aleutians West Census Area
# 3015                  02050              Alaska          Bethel Census Area
# 3034                  02070              Alaska      Dillingham Census Area
# 3078                  02110              Alaska     Juneau City and Borough
# ...                     ...                 ...                         ...
# 137279                56027             Wyoming             Niobrara County
# 137381                56037             Wyoming           Sweetwater County
# 137399                56039             Wyoming                Teton County
# 138115                72049         Puerto Rico           Culebra Municipio
# 139346                72147         Puerto Rico           Vieques Municipio
#
#        Work County FIPS Work State Name            Work County Name  commute  \
# 2959              02013          Alaska      Aleutians East Borough   2504.0
# 2963              02016          Alaska  Aleutians West Census Area   3788.0
# 3015              02050          Alaska          Bethel Census Area   6017.0
# 3034              02070          Alaska      Dillingham Census Area   1782.0
# 3078              02110          Alaska     Juneau City and Borough  17273.0
# ...                 ...             ...                         ...      ...
# 137279            56027         Wyoming             Niobrara County   1006.0
# 137381            56037         Wyoming           Sweetwater County  21644.0
# 137399            56039         Wyoming                Teton County  13175.0
# 138115            72049     Puerto Rico           Culebra Municipio    661.0
# 139346            72147     Puerto Rico           Vieques Municipio   2808.0
#
#         error  resident_weight  resident_weight_total
# 2959    148.0         1.000000                 2356.0
# 2963    114.0         1.000000                 3674.0
# 3015    215.0         0.999483                 5805.0
# 3034     86.0         0.998234                 1699.0
# 3078    435.0         0.999525                16846.0
# ...       ...              ...                    ...
# 137279  123.0         1.000000                  883.0
# 137381  587.0         0.991431                21239.0
# 137399  550.0         0.994251                12698.0
# 138115  166.0         1.000000                  495.0
# 139346  356.0         1.000000                 2452.0
#
# [62 rows x 10 columns]

# %% [markdown]
# ## Method 2: use work commute sum to normalize

# %%
# preprocess: compute the lower bound for commute
table1['work_weight'] = np.maximum(0, table1['commute'] - table1['error'])
total_weight = table1.groupby("Work County FIPS")['work_weight'].sum()

# %%
# preprocess: compute the weight
table1 = table1.join(total_weight, on='Work County FIPS', rsuffix='_total')
table1['work_weight'] = table1['work_weight'] / table1['work_weight_total']

# %%
# visualize the high work weight areas
table1[table1['work_weight'] > 0.99]
# Out:
#        Resident County FIPS Resident State Name          Resident County Name  \
# 2959                  02013              Alaska        Aleutians East Borough
# 3015                  02050              Alaska            Bethel Census Area
# 3034                  02070              Alaska        Dillingham Census Area
# 3041                  02090              Alaska  Fairbanks North Star Borough
# 3062                  02100              Alaska                Haines Borough
# ...                     ...                 ...                           ...
# 131858                54071       West Virginia              Pendleton County
# 137083                56013             Wyoming                Fremont County
# 137279                56027             Wyoming               Niobrara County
# 138115                72049         Puerto Rico             Culebra Municipio
# 139346                72147         Puerto Rico             Vieques Municipio
#
#        Work County FIPS Work State Name              Work County Name  \
# 2959              02013          Alaska        Aleutians East Borough
# 3015              02050          Alaska            Bethel Census Area
# 3034              02070          Alaska        Dillingham Census Area
# 3041              02090          Alaska  Fairbanks North Star Borough
# 3062              02100          Alaska                Haines Borough
# ...                 ...             ...                           ...
# 131858            54071   West Virginia              Pendleton County
# 137083            56013         Wyoming                Fremont County
# 137279            56027         Wyoming               Niobrara County
# 138115            72049     Puerto Rico             Culebra Municipio
# 139346            72147     Puerto Rico             Vieques Municipio
#
#         commute   error  resident_weight  resident_weight_total  work_weight  \
# 2959     2504.0   148.0         1.000000                 2356.0     0.997038
# 3015     6017.0   215.0         0.999483                 5805.0     0.997250
# 3034     1782.0    86.0         0.998234                 1699.0     0.997647
# 3041    49307.0  1028.0         0.988250                48853.0     0.996347
# 3062     1271.0   181.0         0.984643                 1107.0     0.997255
# ...         ...     ...              ...                    ...          ...
# 131858   1988.0   169.0         0.807368                 2253.0     0.990741
# 137083  16698.0   508.0         0.984853                16439.0     0.996983
# 137279   1006.0   123.0         1.000000                  883.0     0.993251
# 138115    661.0   166.0         1.000000                  495.0     1.000000
# 139346   2808.0   356.0         1.000000                 2452.0     1.000000
#
#         work_weight_total
# 2959               2363.0
# 3015               5818.0
# 3034               1700.0
# 3041              48456.0
# 3062               1093.0
# ...                   ...
# 131858             1836.0
# 137083            16239.0
# 137279              889.0
# 138115              495.0
# 139346             2452.0
#
# [93 rows x 12 columns]

# %%
# preprocess: drop unused cols
table1['raw_weight'] = np.maximum(0, table1['commute'] - table1['error'])
final = table1[['Resident County FIPS', 'Work County FIPS', 'resident_weight', 'work_weight', 'raw_weight']]

# %%
final
# Out:
#        Resident County FIPS Work County FIPS  resident_weight  work_weight  \
# 0                     01001            01001         0.386708     0.715450
# 1                     01001            01013         0.000000     0.000000
# 2                     01001            01021         0.013216     0.030582
# 3                     01001            01043         0.000000     0.000000
# 4                     01001            01047         0.007949     0.014844
# ...                     ...              ...              ...          ...
# 139427                72153            72127         0.003106     0.000089
# 139428                72153            72133         0.000000     0.000000
# 139429                72153            72147         0.000000     0.000000
# 139430                72153            72149         0.000000     0.000000
# 139431                72153            72153         0.677329     0.722544
#
#         raw_weight
# 0           8076.0
# 1              0.0
# 2            276.0
# 3              0.0
# 4            166.0
# ...            ...
# 139427        20.0
# 139428         0.0
# 139429         0.0
# 139430         0.0
# 139431      4362.0
#
# [137806 rows x 5 columns]

# %%
# visualize New York County weight
# 36061 is New York County, 36005 is Bronx, 36047 is Kings
final[final['Resident County FIPS'] == '36061'].sort_values('resident_weight', ascending=False)
# Out:
#       Resident County FIPS Work County FIPS  resident_weight  work_weight  \
# 78788                36061            36061         0.863014     0.304687
# 78776                36061            36005         0.032239     0.075522
# 78785                36061            36047         0.031432     0.032247
# 78794                36061            36081         0.024835     0.030259
# 78805                36061            36119         0.009248     0.018644
# ...                    ...              ...              ...          ...
# 78744                36061            28087         0.000000     0.000000
# 78745                36061            29095         0.000000     0.000000
# 78746                36061            29189         0.000000     0.000000
# 78747                36061            29510         0.000000     0.000000
# 78860                36061            72127         0.000000     0.000000
#
#        raw_weight
# 78788    725962.0
# 78776     27119.0
# 78785     26440.0
# 78794     20891.0
# 78805      7779.0
# ...           ...
# 78744         0.0
# 78745         0.0
# 78746         0.0
# 78747         0.0
# 78860         0.0
#
# [190 rows x 5 columns]

# %%
final.to_csv("../../intermediate/05_spread_score.csv")
