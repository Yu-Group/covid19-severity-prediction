# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from functions import merge_data
from functions import load_medicare_data
from functions import load_respiratory_disease_data
from os.path import join as oj
import math
import re
import joblib
import load_data

# %%
county_info_keys = ['#Cases_3/22/2020', '#Deaths_3/22/2020', 'countyFIPS']
df = load_data.merge_hospital_and_county_data(hospital_info_keys='all', 
                                              county_info_keys=county_info_keys)
df.shape

# %%
# note this many hospitals couldn't be matched to a county - we don't know how to include them!
print(df['countyFIPS'].isna().sum())
# Out:
# 598

# %% [markdown]
# # look at important hospitals

# %%
outcomes = [load_data.outcome_cases, load_data.outcome_deaths]
hospital_keys = ['Facility Name_x', 'County Name_x', 'City_x', 'State_x', 
                 'ICU Beds', 'Total Beds', 'Total Employees', 'Hospital Type',
                 'Mortality national comparison',  'Phone Number',  'Urban or Rural Designation']
d = df[outcomes + hospital_keys]
d = d.sort_values(load_data.outcome_deaths, ascending=False)

# %%
d.head(10)
# Out:
#       #Cases_3/22/2020  #Deaths_3/22/2020  \
# 5912            1040.0               75.0
# 5948            1040.0               75.0
# 6011            1040.0               75.0
# 6472            1040.0               75.0
# 5959            1040.0               75.0
# 6012            1040.0               75.0
# 6007            1040.0               75.0
# 5932            1040.0               75.0
# 5938            1040.0               75.0
# 6004            1040.0               75.0
#
#                                         Facility Name_x    County Name_x  \
# 5912   University of Washington Medical Center-Montlake  King County, WA
# 5948                           EvergreenHealth Kirkland  King County, WA
# 6011                          Navos West Seattle Campus  King County, WA
# 6472                            Swedish  Ballard Campus  King County, WA
# 5959                            Swedish Issaquah Campus  King County, WA
# 6012                        Cascade Behavioral Hospital  King County, WA
# 6007                          Fairfax Behavioral Health  King County, WA
# 5932                            Overlake Medical Center  King County, WA
# 5938                          Harborview Medical Center  King County, WA
# 6004  Seattle Children's Hospital & Regional Medical...  King County, WA
#
#         City_x State_x  ICU Beds  Total Beds  Total Employees  \
# 5912   Seattle      WA      81.0       442.0           4343.0
# 5948  Kirkland      WA      63.0       318.0           3179.0
# 6011   Seattle      WA       0.0        43.0            213.0
# 6472   Seattle      WA       0.0         0.0              0.0
# 5959  Issaquah      WA      18.0       126.0            654.0
# 6012   Tukwila      WA       0.0       137.0            230.0
# 6007  Kirkland      WA       0.0       221.0            354.0
# 5932  Bellevue      WA      32.0       300.0           2281.0
# 5938   Seattle      WA      89.0       413.0           4194.0
# 6004   Seattle      WA      91.0       361.0           5478.0
#
#              Hospital Type Mortality national comparison    Phone Number  \
# 5912  Acute Care Hospitals  Same as the national average  (206) 598-3300
# 5948  Acute Care Hospitals    Above the national average  (425) 899-1000
# 6011           Psychiatric                 Not Available  (206) 933-7299
# 6472                   NaN                           NaN             NaN
# 5959  Acute Care Hospitals  Same as the national average  (425) 313-4000
# 6012           Psychiatric                 Not Available  (206) 244-0180
# 6007           Psychiatric                 Not Available  (425) 821-2000
# 5932  Acute Care Hospitals  Same as the national average  (425) 688-5000
# 5938  Acute Care Hospitals  Same as the national average  (206) 731-3000
# 6004             Childrens                 Not Available  (206) 987-2000
#
#      Urban or Rural Designation
# 5912                      Urban
# 5948                      Urban
# 6011                      Urban
# 6472
# 5959                      Urban
# 6012                      Urban
# 6007                      Urban
# 5932                      Urban
# 5938                      Urban
# 6004                      Urban
